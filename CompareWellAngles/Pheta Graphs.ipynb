# %%
import numpy as np  #Importing NumPy4
import math
import matplotlib.pyplot as plt
import random
import matplotlib.ticker as ticker
import matplotlib
import pandas as pd
import platform




pwo = pd.read_csv('1storage5.csv')
pwo2 = pd.DataFrame(pwo)
storage5 = pwo2.to_numpy()
#print(storage5)

pwoeee = pd.read_csv('1storage10.csv')
pwo2eee = pd.DataFrame(pwoeee)
storage10 = pwo2eee.to_numpy()
#print(storage10)

pwoeeef = pd.read_csv('1storage15.csv')
pwo2eeef = pd.DataFrame(pwoeeef)
storage15 = pwo2eeef.to_numpy()
#print(storage15)

pwoeeefg = pd.read_csv('1storage20.csv')
pwo2eeefg = pd.DataFrame(pwoeeefg)
storage20 = pwo2eeefg.to_numpy()
#print(storage20)

pwoeeefe = pd.read_csv('1storage25.csv')
pwo2eeefe = pd.DataFrame(pwoeeefe)
storage25 = pwo2eeefe.to_numpy()
#print(storage25)

pwoeeefa = pd.read_csv('1storage30.csv')
pwo2eeefa = pd.DataFrame(pwoeeefa)
storage30 = pwo2eeefa.to_numpy()
#print(storage30)

pwoeeefb = pd.read_csv('1storage35.csv')
pwo2eeefb = pd.DataFrame(pwoeeefb)
storage35 = pwo2eeefb.to_numpy()
#print(storage35)

pwoeeefv = pd.read_csv('1storage40.csv')
pwo2eeefv = pd.DataFrame(pwoeeefv)
storage40 = pwo2eeefv.to_numpy()
#print(storage40)

pwoeeefp = pd.read_csv('1storage45.csv')
pwo2eeefp = pd.DataFrame(pwoeeefp)
storage45 = pwo2eeefp.to_numpy()
#print(storage45)



pwoeeefpa = pd.read_csv('1storage50.csv')
pwo2eeefpa = pd.DataFrame(pwoeeefpa)
storage50 = pwo2eeefpa.to_numpy()
#print(storage50)

# %%
pwo = pd.read_csv('testpheta.csv')
pwo2 = pd.DataFrame(pwo)
dls = pwo2.to_numpy()
d1 = dls[0:1800,0]
d1 = d1 + 100

#print(d1)

# %%
Flowrate_Initial = [5,10,15,20,25,30,35,40,45,50]


matplotlib.rcParams.update({'font.size': 20})
matplotlib.rcParams.update({'font.weight': 'bold'})


is_windows = any(platform.win32_ver())
if is_windows==True:
    path=r'CustomPath'
else:
    path=r'/Users/willba/Desktop/pheta'

fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage5[:,0],storage5[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage5[:,0],storage5[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage5[:,0],storage5[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage5[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[0])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage5[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle5.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage5[:,0],storage5[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage5[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[0])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle5press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage10[:,0],storage10[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage10[:,0],storage10[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage10[:,0],storage10[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage10[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[1])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage10[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle10.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage10[:,0],storage10[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage10[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[1])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle10press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage15[:,0],storage15[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage15[:,0],storage15[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage15[:,0],storage15[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage15[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[2])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage15[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle15.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage15[:,0],storage15[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage15[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[2])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle15press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage20[:,0],storage20[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage20[:,0],storage20[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage20[:,0],storage20[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage20[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[3])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage20[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle20.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage20[:,0],storage20[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage20[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[3])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle20press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage25[:,0],storage25[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage25[:,0],storage25[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage25[:,0],storage25[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage25[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[4])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage25[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle25.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage25[:,0],storage25[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage25[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[4])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle25press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage30[:,0],storage30[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage30[:,0],storage30[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage30[:,0],storage30[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage30[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[5])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage30[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle30.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage30[:,0],storage30[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage30[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[5])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle30press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage35[:,0],storage35[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage35[:,0],storage35[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage35[:,0],storage35[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage35[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[6])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage35[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle35.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage35[:,0],storage35[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage35[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[6])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle35press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage40[:,0],storage40[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage40[:,0],storage40[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage40[:,0],storage40[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage40[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[7])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage40[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle40.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage40[:,0],storage40[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage40[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[7])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle40press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage45[:,0],storage45[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage45[:,0],storage45[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage45[:,0],storage45[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage45[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[8])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage45[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle45.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage45[:,0],storage45[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage45[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[8])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle45press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage50[:,0],storage50[:,1],'r',marker = 'o',markersize = 11)
plt.plot(storage50[:,0],storage50[:,2],'b',marker = 'o',markersize = 11)
plt.plot(storage50[:,0],storage50[:,3],'g',marker = 'o',markersize = 11)

plt.xticks(np.arange(0, max(storage50[:,0])+1, 1))

plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Flow Distribution (%)', fontsize = 20, fontweight = 'bold')
plt.title('Flow Distribution vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[9])+' kg/s',fontsize = 20, fontweight = 'bold')
plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
plt.hlines(100/3, 0, max(storage50[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/wellangle50.png' %path, bbox_inches='tight')


fig2 = plt.figure(2)
ax2 = fig2.gca()
for axis in [ax2.xaxis, ax2.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig2.set_figwidth(18)
fig2.set_figheight(18)

plt.plot(storage50[:,0],storage50[:,4],'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage50[:,0])+1, 1))
plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Pressure Drop (PSI)', fontsize = 20, fontweight = 'bold')
plt.title('Pressure Drop vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations\n'+str(Flowrate_Initial[9])+' kg/s',fontsize = 20, fontweight = 'bold')


plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig2.savefig(r'%s/wellangle50press.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage40[:,0],d1,'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage40[:,0])+1, 10))

#plt.xlim(0,15)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Fracture Length (m)', fontsize = 20, fontweight = 'bold')
plt.title('Fracture Length vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations',fontsize = 20, fontweight = 'bold')
#plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
#plt.hlines(100/3, 0, max(storage40[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/distance.png' %path, bbox_inches='tight')

# %%
fig = plt.figure(1)
ax = fig.gca()
for axis in [ax.xaxis, ax.yaxis]:
    axis.set_major_locator(ticker.MaxNLocator(integer=True))
fig.set_figwidth(18)
fig.set_figheight(18)

plt.plot(storage40[:,0],d1,'r',marker = 'o',markersize = 11)


plt.xticks(np.arange(0, max(storage40[:,0])+1, 1))

plt.xlim(0,15)
plt.ylim(0,800)
plt.xlabel('Well Angle (Degrees)', fontsize = 20, fontweight = 'bold')
plt.ylabel('Fracture Length (m)', fontsize = 20, fontweight = 'bold')
plt.title('Fracture Length (m) vs. Well Angle\n Using no Exit Perforations\n Non-Parallel Well Design\n50 Inlet Perforations',fontsize = 20, fontweight = 'bold')
#plt.legend(['Fracture 1(Heel)','Fracture 2','Fracture 3(Toe)'], fontsize = 20)
#plt.hlines(100/3, 0, max(storage40[:,0]), colors='k', linestyles='solid',zorder=3)
plt.grid(which='major', axis='both',color='lightgrey',zorder=1)
fig.savefig(r'%s/distance2.png' %path, bbox_inches='tight')
